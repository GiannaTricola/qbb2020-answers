# %%
file_ctab = open('/Users/cmdb/data/results/stringtie/SRR072893/t_data.ctab', 'r')

# %% [markdown]
# # Find most abundant gene
#     1. Open t_data cile
#     2. Look line by line
#         3. Read FPKM and gene_name from that line
#         4. if new FPKM is larger than previous FPKM then store the larger FPKM and gene_name
#     5. At end print gene with the highest one
# # Second approach
#     1. Store list
#     2. Find max

# %%
file_ctab = open('/Users/cmdb/data/results/stringtie/SRR072893/t_data.ctab', 'r')
max_FPKM = 0.0
max_gene = ''
for i, line in enumerate(file_ctab):
    if i == 0:
        continue
        #print(type(line))
        #print(i, line)
    column_info = line.split()
    gene_name = column_info[9]
    FPKM = float(column_info[11])
        #print(gene_name, FPKM)
    if FPKM > max_FPKM:
        max_FPKM = FPKM
        max_gene = gene_name
print(max_gene, max_FPKM)
# Out:
# Ef1alpha48D 6517.760254

# %%
file_ctab = open('/Users/cmdb/data/results/stringtie/SRR072893/t_data.ctab', 'r')

FPKMs={}
for i, line in enumerate (file_ctab):
    if i == 0:
        continue
        #print(type(line))
        #print(i, line)
    column_info = line.split()
    t_name = column_info[5]
    FPKM = float(column_info[11])
    FPKMs[t_name] = FPKM
len(FPKMs.keys() )
# Out:
# 34718

# %%
#for t_name in FPKMs:
    #if FPKMs[t_name] >100:
        #print(t_name, FPKMs[gene])
        
max2_FPKM = max(FPKMs.values())
FPKMs[t_name] = max2_FPKM
print(t_name, max2_FPKM)
# Out:
# FBtr0114283 6517.760254

# %%
fs = open('/Users/cmdb/data/results/stringtie/SRR072893/t_data.ctab', 'r')
t1 = []
for i, line in enumerate(fs):
    if i== 0:
        continue
    fields = line.split()[9]
    print(fields)
# Out:
# CR41571
# CG45784
# CR12798
# CR40182
# CG45783
# CR45220
# CR45220
# spok
# Parp
# Alg-2
# Tim17b
# Tim17b
# CG41128
# CG41099
# CG41099
# CG41099
# CG41099
# CG42402
# CG42402
# CG42402
# Gfat1
# Gfat1
# Gfat1
# Gfat1
# Gfat1
# Gfat1
# Gfat1
# Gfat1
# Gfat1
# CR41601
# CG40198
# CG40198
# CG12581
# CG12581
# CR33294
# Dsk
# CR33294
# CG12582
# CG12582
# CG12582
# CG12582
# CG12582
# CG14636
# CG14636
# aux
# CG31516
# aux
# aux
# aux
# DhpD
# CG14641
# abs
# Gel
# Gel
# Gel
# Gel
# Gel
# Gel
# Gel
# CG14642
# CG14642
# CG14642
# CG34305
# TwdlU
# TwdlF
# TwdlG
# TwdlG
# TwdlG
# CG14644
# CG14644
# TwdlV
# Or82a
# CG1092
# CG1092
# CG9766
# CR45597
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# cpx
# CG9780
# cpx
# mir-929
# mir-929
# MP1
# MP1
# Vps24
# CG9791
# Syt14
# Syt14
# Syt14
# CG9795
# CG9795
# CG9795
# CG9795
# CG9776
# CG9776
# Skp2
# CG14645
# Skp2
# CG1103
# CG1103
# hkb
# CG1090
# CG1090
# CG1090
# ...
